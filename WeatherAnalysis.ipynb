# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\PHILOMENA LOT\Desktop\udemyproject\weatheranalysis\weather.csv")

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#Data has been read successfully

# %%
DATAFRAME ANALYSIS

# %%
#Lets inspect a sample of our data
data.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
#Show our full dataframe to see the size we are working with
data.shape
# Out:
# (366, 22)

# %%
#attribute index to confirm size
data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
#view columns only
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#Show the datatype in each column
data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
#Show the wind directions
data["WindGustDir"].unique()
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
#Show the wind directions at 9am
data["WindDir9am"].unique()
# Out:
# array(['SW', 'E', 'N', 'WNW', 'SSE', 'SE', 'S', 'WSW', 'NNE', 'NNW',
#        'ENE', 'SSW', 'NW', 'ESE', 'NE', 'W', nan], dtype=object)

# %%
#Show the wind directions at 3pm
data["WindDir3pm"].unique()
# Out:
# array(['NW', 'W', 'NNE', 'ESE', 'E', 'ENE', 'WSW', 'NE', 'NNW', 'SE', 'S',
#        'SW', 'WNW', 'N', 'SSW', 'SSE', nan], dtype=object)

# %%
#Number of wind directions
data["WindGustDir"].nunique()
# Out:
# 16

# %%
#Number of wind directions at 9am
data["WindDir9am"].nunique()
# Out:
# 16

# %%
#Number of wind directions at 3pm
data["WindDir3pm"].nunique()
# Out:
# 16

# %%
#Check for nullvalues in each column
data.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
#Column; Sunshine, WindGustDir, WindGustSpeed,WindGustDir9am, WindGustDir3pm,  WindGustSpeed9am, have null values

# %%
data["WindGustDir"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       NW
# 1      ENE
# 2       NW
# 3       NW
# 4      SSE
#       ...
# 361    NNW
# 362      N
# 363    ESE
# 364     NW
# 365     NW
# Name: WindGustDir, Length: 366, dtype: object>

# %%
#Show database Schema
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
#Now we know what we are working with we can start our analysis

# %%
Find all the unique 'Wind Speed' Values

# %%
#Lets view our columns
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
#View the number of unique values
data["WindGustSpeed"].nunique()
# Out:
# 35

# %%
#show all unique values under wind speed
data["WindGustSpeed"].unique()
# Out:
# array([30., 39., 85., 54., 50., 44., 43., 41., 48., 31., 46., 52., 33.,
#        59., 26., 28., 35., 22., 76., 65., 57., 69., 61., 24., 83., 63.,
#        17., 20., nan, 15., 13., 70., 78., 67., 98., 80.])

# %%
Find the number of time when the "Weather is exactly clear"

# %%
#Weather is exactly clear when sunshine is above 10
#View our Sunshine column
data["Sunshine"].unique()
# Out:
# array([ 6.3,  9.7,  3.3,  9.1, 10.6,  8.2,  8.4,  4.6,  4.1,  7.7, 11.9,
#        12.5, 13. , 12.4, 13.1, 11.1, 10.1, 10.4,  9.5,  0. ,  0.6,  7.5,
#         8.1,  8.9,  2.3, 10.7,  0.4,  0.5,  0.2, 12. ,  4.7, 11.8,  9.8,
#         8.8, 10. ,  7.3,  3.6, 12.7,  0.9,  8.7,  0.8,  5.9, 10.2, 12.1,
#         5.6,  7.1, 13.2, 13.6, 12.8, 10.5,  2.2, 11.7, 12.6, 13.3,  6.9,
#        13.5,  6. , 11.6,  0.1,  1.6, 10.8,  9.9,  9. ,  6.2,  9.2,  0.3,
#         8. ,  9.6,  3.8,  8.6, 11. , 11.3, 11.5, 11.2,  8.5, 11.4,  1.9,
#        10.3,  9.3,  7.8,  6.8,  6.1,  8.3,  4.9,  7.9,  6.5,  5.8,  7. ,
#         9.4,  3. ,  4.3,  1.7,  6.7,  5.1,  2.7,  2.6,  nan,  7.2,  2. ,
#         7.6,  6.4,  3.9,  2.8,  1.2,  5.2,  0.7,  4.2,  5. ,  1.8,  2.4,
#         2.9, 10.9, 12.2,  3.5,  5.3])

# %%
#Show the table with clear days only
NumberOfClearWeathers = data[data["Sunshine"] >= 10].groupby("Sunshine")
for group, group_df in NumberOfClearWeathers:
    print(f"Sunshine: {group}")
    print(group_df)
    print()
# Out:
# Sunshine: 10.0
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 39      14.9     24.8       0.0         10.4      10.0         NNW
# 149      7.1     18.5       0.0          3.4      10.0          NW
# 151      9.6     18.8       0.0          6.4      10.0         WNW
# 289      3.7     14.2       0.0          3.0      10.0         NNW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 39            35.0        NNE        WNW          11.0  ...           37
# 149           57.0          N         NW           9.0  ...           30
# 151           57.0         NW          W          19.0  ...           42
# 289           46.0        WNW        WSW          24.0  ...           27
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 39        1011.7       1010.4         7         7     19.3     22.9
# 149       1015.1       1011.3         6         6      8.8     18.2
# ...

# %%
Find the number of times when the "Wind speed was wxactly 44km/h'

# %%
#Inspect our table to see the formatting for the column 
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#Count the number of each unique value to know what our result should look like
data["WindGustSpeed"].value_counts()
# Out:
# WindGustSpeed
# 41.0    32
# 39.0    31
# 31.0    30
# 35.0    24
# 30.0    23
# 46.0    23
# 33.0    19
# 43.0    18
# 48.0    18
# 50.0    16
# 44.0    15
# 28.0    15
# 22.0    11
# 52.0    10
# 26.0    10
# 59.0     9
# 20.0     9
# 17.0     7
# 24.0     6
# 65.0     6
# 57.0     6
# 70.0     4
# 54.0     4
# 78.0     2
# 76.0     2
# 63.0     2
# 15.0     2
# 13.0     2
# 61.0     2
# 67.0     1
# 98.0     1
# 83.0     1
# 69.0     1
# 85.0     1
# 80.0     1
# Name: count, dtype: int64

# %%
#SHOW THE RESULT FOR WHEN WIND SPEED IS EXACTLY 44KM/H
data[data["WindGustSpeed"] == 44]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 16      13.8     31.2       0.0          7.2       8.4         ESE
# 53      12.4     24.4       0.0          6.2      12.1          NW
# 88      15.3     33.2       0.0          9.4      13.2         NNW
# 115     12.0     23.8       0.0         10.4      12.4          NW
# 116     11.5     25.9       0.0          5.2      10.2         ENE
# 117     13.0     28.2       0.0          5.0      11.6          NW
# 132     13.3     31.7       0.2          7.8      11.0         WNW
# 177      3.8     21.7       0.2          2.8       6.5          NW
# 286      2.3     12.2       0.0          2.8       9.8         WNW
# 323      5.1     23.3       0.0          3.6      10.3          NW
# 330      2.5     20.9       0.0          3.6      10.6         NNW
# ...

# %%
FIND OUT ALL THE NULL VALUES IN THE DATA

# %%
#Show the sum of null values in each column
data.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
#RENAME THE COLUMN NAME WindSpeed9am to WindSpeedAt9am

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.rename(columns = {"WindSpeed9am" : "WindSpeedAt9am"})
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeedAt9am  ...  Humidity3pm  \
# 0             30.0         SW         NW             6.0  ...           29
# ...

# %%
#WHAT IS THE MEAN PRESSURE AT 3PM

# %%
#inspect data
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
#Calculate the mean pressure at 3pm
data.Pressure3pm.mean()
# Out:
# 1016.8103825136611

# %%
#WHAT IS THE STANDARD DEVIATION OF PRESSURE IN THIS DATA

# %%
data.Pressure3pm.std()
# Out:
# 6.469422397297334

# %%
#WHAT IS THE VARIANCE OF HUMIDITY BY 3PM IN THIS DATA?

# %%
data.Humidity3pm.var()
# Out:
# 283.95442772662625

# %%
#FIND ALL THE INSTANCES WIND BLEW IN NORTHWEST DIRECTION

# %%
#View our data
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
#Show data filtered by NorthWest wind direction
data[data["WindGustDir"] == "NW"]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 14      10.1     31.2       0.0          8.8      13.1          NW
# ..       ...      ...       ...          ...       ...         ...
# 352      6.7     24.7       0.0          5.4       8.6          NW
# 353      8.3     28.5       0.0          5.8       9.8          NW
# 354     11.3     27.4       0.2          7.6      12.1          NW
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#FIND ALL THE INSTANCES WHEN WIND SPEED IS ABOVE 50 AND EVAPORATION IS 5.0

# %%
data[(data["WindGustSpeed"] >= 46) & (data["Evaporation"] == 5.0)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 316     -0.5     21.6       0.0          5.0       9.9          NW
# 364     12.5     26.9       0.0          5.0       7.1          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 316           48.0        NNE         NW           9.0  ...           27
# 364           46.0        SSW        WNW           6.0  ...           39
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 316       1014.6       1010.9         7         5     11.9     21.5
# 364       1021.0       1016.2         6         7     15.8     25.9
#
#      RainToday  RISK_MM RainTomorrow
# 316         No      0.0           No
# 364         No      0.0           No
#
# [2 rows x 22 columns]

# %%
#WHAT IS THE MEAN VALUE OF EACH COLUMN AGAINST EACH "WINDGUSTSPEED"

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.WindGustSpeed.mean()
# Out:
# 39.84065934065934

# %%
#SHOW INSTANCES OF THE MAXIMUM AND MINIMUM VALUE OF THE WIND SPEED

# %%
#WHAT IS THE MINIMUM VALUE OF EACH COLUMN AGAINST EACH "WINDGUSTSPEED"

# %%
data.WindGustSpeed.min()
# Out:
# 13.0

# %%
#WHAT IS THE MAXIMUM VALUE OF EACH COLUMN AGAINST EACH "WINDGUSTSPEED"

# %%
data.WindGustSpeed.max()
# Out:
# 98.0

# %%
#SHOW RECORDS OF BOTH MINIMUM AND MAXIMUM VALUE
data[(data["WindGustSpeed"] == 13.0) | (data["WindGustSpeed"] == 98.0)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 230      0.4     15.5       0.0          1.0       4.7           N
# 247     -0.1     14.2       0.0          1.4       7.0           W
# 319      8.7     19.7       1.6          5.2       8.0          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 230           13.0          N        NNW           6.0  ...           70
# 247           13.0        NaN        WNW           NaN  ...           55
# 319           98.0         NW        NNW          31.0  ...           33
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 230       1026.7       1023.5         5         7      4.0     15.0
# 247       1032.9       1028.9         1         2      4.7     12.6
# 319       1009.1       1001.5         3         6     15.6     18.5
#
#      RainToday  RISK_MM RainTomorrow
# 230         No      0.0           No
# 247         No      0.0           No
# ...

# %%
#SHOW ALL THE WIND DIRECTION RECORDS WHERE IT RAINED ON THAT DAY OR THE WIND SPEED WAS GREATER THAN 50

# %%
Directions = data[(data["RainToday"] == 'Yes') | (data["WindGustSpeed"] >= 50)]
Directions["WindGustDir"].value_counts()
# Out:
# WindGustDir
# NW     29
# WNW    15
# NNW    15
# S      12
# W      11
# ESE     6
# ENE     5
# SSE     5
# E       5
# N       3
# NE      2
# SSW     2
# NNE     1
# SW      1
# Name: count, dtype: int64

# %%
#SHOW THE INSTANCES WHERE RAIN DID NOT FALL THAT DAY AND HUMIDITY IS LESS THAN 70
OR
#RAINFALL IS ABOVE 10

# %%
#View Data
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data[((data["RainToday"] == 'No') & (data["Humidity3pm"] <= 70)) | (data["Rainfall"] >= 10)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...
